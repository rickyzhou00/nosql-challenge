# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd
import pymongo
import re

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
collection_names = db.list_collection_names()
collection_names
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
hygiene = establishments.find({"scores.Hygiene": 20})

# Use count_documents to display the number of documents in the result
count = establishments.count_documents({'scores.Hygiene': 20})
count
# Out:
# 41

# %%
# Display the first document in the results using pprint
pprint(hygiene[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('645ac7436468bb11210eb562'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
hygiene_df = pd.DataFrame(hygiene)

# Display the number of rows in the DataFrame
print(len(hygiene_df))
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
print(hygiene_df.head(10))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  645ac7436468bb11210eb562   110681                  0
# 1  645ac7436468bb11210eb8e3   612039                  0
# 2  645ac7436468bb11210ebbed   730933                  0
# 3  645ac7436468bb11210ebddb   172735                  0
# 4  645ac7436468bb11210ebdea   172953                  0
# 5  645ac7436468bb11210ec788   512854                  0
# 6  645ac7436468bb11210ec9a9  1537089                  0
# 7  645ac7436468bb11210eded5   155648                  0
# 8  645ac7436468bb11210ee319  1012883                  0
# 9  645ac7446468bb11210eeb2d   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                       LocalAuthorityWebSite  \
# 0  http://www.eastbourne.gov.uk/foodratings
# 1             http://www.tendringdc.gov.uk/
# 2             http://www.tendringdc.gov.uk/
# 3       http://www.lewes-eastbourne.gov.uk/
# 4       http://www.lewes-eastbourne.gov.uk/
# 5                http://www.southend.gov.uk
# 6                http://www.southend.gov.uk
# 7                http://www.rochford.gov.uk
# 8              http://www.sevenoaks.gov.uk/
# 9                http://www.basildon.gov.uk
#
#               LocalAuthorityEmailAddress  \
# 0        Customerfirst@eastbourne.gov.uk
# 1             fhsadmin@tendringdc.gov.uk
# 2             fhsadmin@tendringdc.gov.uk
# 3    ehealth.ldc@lewes-eastbourne.gov.uk
# 4    ehealth.ldc@lewes-eastbourne.gov.uk
# 5    EnvironmentalHealth@southend.gov.uk
# 6    EnvironmentalHealth@southend.gov.uk
# 7       customerservices@rochford.gov.uk
# 8  environmental.health@sevenoaks.gov.uk
# 9                    ehs@basildon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...        FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...        FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...        FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...        FHRS
#
#                                              geocode RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'https://api.ratings....
# 2  [{'rel': 'self', 'href': 'https://api.ratings....
# 3  [{'rel': 'self', 'href': 'https://api.ratings....
# 4  [{'rel': 'self', 'href': 'https://api.ratings....
# 5  [{'rel': 'self', 'href': 'https://api.ratings....
# 6  [{'rel': 'self', 'href': 'https://api.ratings....
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Define the regular expression pattern
pattern = re.compile(r"\bLondon\b", re.IGNORECASE)

# Find establishments in London with a rating value greater than or equal to 4
london_establishments = establishments.find(
    {
        "LocalAuthorityName": {"$regex": pattern},
        "RatingValue": {"$gte": 4}
    }
)

# Print the number of establishments in the result
print("Total number of establishments in London with a rating value greater than or equal to 4:", london_establishments.count())
# Out:
# Total number of establishments in London with a rating value greater than or equal to 4: 33
# C:\Users\Pradivan\AppData\Local\Temp\ipykernel_20936\3774059134.py:13: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   print("Total number of establishments in London with a rating value greater than or equal to 4:", london_establishments.count())

# %%
# Display the first document in the results using pprint
pprint(london_establishments[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('645ac7436468bb11210ecf7d'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}

# %%
# Convert the cursor object to a list
london_establishments_list = list(london_establishments)

# Convert the list to a Pandas DataFrame
df_london_establishments = pd.DataFrame(london_establishments_list)

# %%
# Display the first 10 rows of the DataFrame
print(df_london_establishments.head(10))
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  645ac7436468bb11210ecf7d   621707                  0
# 1  645ac7436468bb11210ed2a4  1130836                  0
# 2  645ac7436468bb11210eddf0   293783                  0
# 3  645ac7446468bb11210eebf0  1315095                  0
# 4  645ac7446468bb11210eebf1   294474                  0
# 5  645ac7446468bb11210ef2f9   294900                  0
# 6  645ac7446468bb11210f1408   293756                  0
# 7  645ac7446468bb11210f17ce   878523                  0
# 8  645ac7446468bb11210f17e8   293772                  0
# 9  645ac7446468bb11210f17e9   295107                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000020749                      City Bar & Grill
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9  Restaurant/Cafe/Canteen               1
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                      London City Airport (Airside)
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                                London               ...
#
#                                LocalAuthorityWebSite  \
# 0  http://www.cityoflondon.gov.uk/Corporation/hom...
# 1  http://www.cityoflondon.gov.uk/Corporation/hom...
# 2  http://www.cityoflondon.gov.uk/Corporation/hom...
# 3  http://www.cityoflondon.gov.uk/Corporation/hom...
# 4  http://www.cityoflondon.gov.uk/Corporation/hom...
# 5  http://www.cityoflondon.gov.uk/Corporation/hom...
# 6  http://www.cityoflondon.gov.uk/Corporation/hom...
# 7  http://www.cityoflondon.gov.uk/Corporation/hom...
# 8  http://www.cityoflondon.gov.uk/Corporation/hom...
# 9  http://www.cityoflondon.gov.uk/Corporation/hom...
#
#              LocalAuthorityEmailAddress  \
# 0  publicprotection@cityoflondon.gov.uk
# 1  publicprotection@cityoflondon.gov.uk
# 2  publicprotection@cityoflondon.gov.uk
# 3  publicprotection@cityoflondon.gov.uk
# 4  publicprotection@cityoflondon.gov.uk
# 5  publicprotection@cityoflondon.gov.uk
# 6  publicprotection@cityoflondon.gov.uk
# 7  publicprotection@cityoflondon.gov.uk
# 8  publicprotection@cityoflondon.gov.uk
# 9  publicprotection@cityoflondon.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
#
#                                              geocode RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8     {'longitude': 0.047966, 'latitude': 51.504112}
# 9  {'longitude': 0.0479655750095844, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'https://api.ratings....
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
print(db.establishments.find_one()["geocode"]["latitude"].__class__.__name__)
print(db.establishments.find_one()["geocode"]["longitude"].__class__.__name__)
# Out:
# Decimal128
# Decimal128

# %%
# Find the new restaurant "Penang Flavours"
new_restaurant = establishments.find_one({"BusinessName": "Penang Flavours"})

# Define the search range
search_range = 0.01 

# Convert the latitude and longitude of the new restaurant to float
latitude = float(new_restaurant["geocode"]["latitude"].to_decimal())
longitude = float(new_restaurant["geocode"]["longitude"].to_decimal())

# Search for restaurants within 0.01 degree latitude and longitude of Penang Flavours and Rating value must equal 5
nearby = establishments.find(
    {
        "geocode.latitude": {"$gte": latitude - search_range, "$lte": latitude + search_range},
        "geocode.longitude": {"$gte": longitude - search_range, "$lte": longitude + search_range},
        "RatingValue": {"$eq": 5}
    }
).sort([("scores.Hygiene", pymongo.ASCENDING)])

# Print the number of establishments in the result
print("Total number of establishments in with rating value of 5 within 0.1 degree of Penang Flavours:", nearby.count())
# Out:
# Total number of establishments in with rating value of 5 within 0.1 degree of Penang Flavours: 50
# C:\Users\Pradivan\AppData\Local\Temp\ipykernel_20936\1297622549.py:21: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   print("Total number of establishments in with rating value of 5 within 0.1 degree of Penang Flavours:", nearby.count())

# %%
pprint(nearby[0])
# Out:
# {'AddressLine1': '',
#  'AddressLine2': 'Langley Crescent',
#  'AddressLine3': '',
#  'AddressLine4': 'Dagenham',
#  'BusinessName': 'James Cambell Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4647.385014639661,
#  'FHRSID': 106490,
#  'LocalAuthorityBusinessID': '3701',
#  'LocalAuthorityCode': '501',
#  'LocalAuthorityEmailAddress': 'foodsafety@lbbd.gov.uk',
#  'LocalAuthorityName': 'Barking and Dagenham',
#  'LocalAuthorityWebSite': 'http://www.lbbd.gov.uk/Pages/Home.aspx',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'RM9 6TD',
#  'RatingDate': '2021-11-05T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('645ac7446468bb11210f1055'),
#  'geocode': {'latitude': Decimal128('51.536304'),
#              'longitude': Decimal128('0.129873')},
#  'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/106490',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert the result to a Pandas DataFrame
nearby_df = pd.DataFrame(nearby)

# %%
nearby_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  645ac7446468bb11210f1055   106490                0.0
# 1  645ac7446468bb11210f1064   128159                0.0
# 2  645ac7446468bb11210f1065   950704                0.0
# 3  645ac7446468bb11210f1066  1210200                0.0
# 4  645ac7446468bb11210f1102   128811                0.0
# 5  645ac7446468bb11210f1114   105018                0.0
# 6  645ac7446468bb11210f1115    91591                0.0
# 7  645ac7446468bb11210f1117   415585                0.0
# 8  645ac7446468bb11210f111d   110607                0.0
# 9  645ac7446468bb11210f1122  1518914                0.0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0                     3701                       James Cambell Primary School
# 1                    57988                     Jo Richardson Secondary School
# 2                    69962                               Castle Green Nursery
# 3                    75292  Jo Richardson Community School - Social Kitche...
# 4                    59086                                       Crowned Kids
# 5                     3598                          Angies Cafe and Kebab Ltd
# 6                      254                                      Co-op Welcome
# 7                    42134                        Keith Davis Cue Sports Club
# 8                    40230                                             Greggs
# 9                    78713                                            Martins
#
#                             BusinessType  BusinessTypeID AddressLine1  \
# 0              School/college/university            7845
# 1              School/college/university            7845
# 2                        Caring Premises               5
# 3                Restaurant/Cafe/Canteen               1
# 4                        Caring Premises               5
# 5                 Takeaway/sandwich shop            7844
# 6  Retailers - supermarkets/hypermarkets            7840
# 7                Restaurant/Cafe/Canteen               1
# 8                      Retailers - other            4613
# 9                      Retailers - other            4613
#
#           AddressLine2 AddressLine3  ...  \
# 0     Langley Crescent               ...
# 1          Gale Street               ...
# 2          Gale Street               ...
# 3          Gale Street               ...
# 4      523 Gale Street               ...
# 5      505 Gale Street               ...
# 6     513b Gale Street               ...
# 7  497-505 Gale Street               ...
# 8    12a Woodward Road               ...
# 9     16 Woodward Road               ...
#
#                     LocalAuthorityWebSite LocalAuthorityEmailAddress  \
# 0  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 1  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 2  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 3  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 4  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 5  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 6  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 7  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 8  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
# 9  http://www.lbbd.gov.uk/Pages/Home.aspx     foodsafety@lbbd.gov.uk
#
#                                               scores  SchemeType  \
# 0  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...        FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 3  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 6  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 7  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...        FHRS
#
#                                             geocode RightToReply     Distance  \
# 0    {'longitude': 0.129873, 'latitude': 51.536304}               4647.385015
# 1    {'longitude': 0.126375, 'latitude': 51.533355}               4647.404096
# 2    {'longitude': 0.126375, 'latitude': 51.533355}               4647.404096
# 3    {'longitude': 0.126375, 'latitude': 51.533355}               4647.404096
# 4    {'longitude': 0.127977, 'latitude': 51.539261}               4647.562613
# 5    {'longitude': 0.127901, 'latitude': 51.539793}               4647.584914
# 6    {'longitude': 0.127901, 'latitude': 51.539792}               4647.584877
# 7    {'longitude': 0.127901, 'latitude': 51.539793}               4647.584914
# 8     {'longitude': 0.12701, 'latitude': 51.538928}               4647.585590
# 9  {'longitude': 0.1268614, 'latitude': 51.5389039}               4647.590115
#
#   NewRatingPending                                               meta  \
# 0            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 1            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 2            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 3            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 4            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 5            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 6            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 7            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 8            False  {'dataSource': None, 'extractDate': '0001-01-0...
# 9            False  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...
#
# [10 rows x 28 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
]

local_hygiene = establishments.aggregate(pipeline)

# %%
# Convert the result to a Pandas DataFrame
hygiene_zero_df = pd.DataFrame(list(local_hygiene))

# %%
# Display the number of rows in the DataFrame
print(hygiene_zero_df)
# Out:
#                            _id  count
# 0                       Thanet   1130
# 1                    Greenwich    882
# 2                    Maidstone    713
# 3                       Newham    711
# 4                        Swale    686
# 5                   Chelmsford    680
# 6                       Medway    672
# 7                       Bexley    607
# 8              Southend-On-Sea    586
# 9                     Tendring    542
# 10                  Colchester    498
# 11             Tunbridge Wells    491
# 12        Folkestone and Hythe    480
# 13                  Eastbourne    478
# 14                    Hastings    464
# 15                     Bromley    460
# 16                     Ashford    427
# 17                    Havering    397
# 18                    Dartford    383
# 19                   Braintree    382
# 20                    Basildon    362
# 21                   Gravesham    339
# 22       Tonbridge and Malling    325
# 23                    Thurrock    313
# 24        Barking and Dagenham    301
# 25             Canterbury City    298
# 26                   Brentwood    285
# 27                Castle Point    281
# 28                      Harlow    274
# 29                  Uttlesford    251
# 30                       Lewes    250
# 31                   Sevenoaks    223
# 32                      Maldon    197
# 33          East Hertfordshire    189
# 34                    Rochford    187
# 35                   Redbridge    182
# 36               Epping Forest    180
# 37                East Suffolk    159
# 38              Waltham Forest    110
# 39                     Babergh     97
# 40                     Wealden     93
# 41                      Rother     80
# 42                    Lewisham     65
# 43                   Tandridge     42
# 44  City of London Corporation     28
# 45                     Ipswich     21
# 46               Tower Hamlets      9
# 47         North Hertfordshire      6
# 48                  Mid Sussex      5
# 49                  Broxbourne      1
# 50               North Norfolk      1
# 51                  Sunderland      1
# 52                      Dorset      1
# 53      Kensington and Chelsea      1
# 54                     Reading      1

# %%
# Display the first 10 rows of the DataFrame
print(hygiene_zero_df.head(10))
# Out:
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
